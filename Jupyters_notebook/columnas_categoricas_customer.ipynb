# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("..")

# Paquetes de visualización
import seaborn as sns 
import matplotlib.pyplot as plt 

# Importaciones de unidades de soporte
from SRC import sp_eda, sp_visualizacion

# %%
df_limpio = pd.read_csv('../Data/data_limpios_customer.csv')
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                43170 non-null  int64
#  1   Kid_Home              43170 non-null  int64
#  2   Teen_Home             43170 non-null  int64
#  3   Dt_Customer           43170 non-null  object
#  4   Num_Web_Visits_Month  43170 non-null  int64
#  5   ID                    43170 non-null  object
#  6   Join_Year             43170 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 2.3+ MB

# %%
numero_nulos_df_limpio, porcentaje_nulos_df_limpio = sp_eda.calcular_porcentaje_nulos(df_limpio)

# %%
numero_nulos_df_limpio
# Out:
# Income                  0
# Kid_Home                0
# Teen_Home               0
# Dt_Customer             0
# Num_Web_Visits_Month    0
# ID                      0
# Join_Year               0
# dtype: int64
