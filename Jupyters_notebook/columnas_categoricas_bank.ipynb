# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("..")

# Paquetes de visualización
import seaborn as sns 
import matplotlib.pyplot as plt 

# Importaciones de unidades de soporte
from SRC import sp_eda, sp_visualizacion

# %%
df_limpio = pd.read_csv('../Data/data_limpios_bank.csv')
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job_grouped     42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp_var_rate    43000 non-null  float64
#  14  cons_price_idx  42529 non-null  float64
#  15  cons_conf_idx   43000 non-null  float64
#  16  euribor3m       33744 non-null  float64
# ...

# %%
numero_nulos_df_limpio, porcentaje_nulos_df_limpio = sp_eda.calcular_porcentaje_nulos(df_limpio)

# %%
numero_nulos_df_limpio
# Out:
# age               5120
# job_grouped        345
# marital             85
# education         1807
# default           8981
# housing           1026
# loan              1026
# contact              0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp_var_rate         0
# cons_price_idx     471
# cons_conf_idx        0
# euribor3m         9256
# nr_employed          0
# y                    0
# date               248
# latitude             0
# longitude            0
# id_                  0
# year                 0
# dtype: int64

# %%
porcentaje_nulos_df_limpio
# Out:
# age               11.91
# job_grouped        0.80
# marital            0.20
# education          4.20
# default           20.89
# housing            2.39
# loan               2.39
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp_var_rate       0.00
# cons_price_idx     1.10
# cons_conf_idx      0.00
# euribor3m         21.53
# nr_employed        0.00
# y                  0.00
# date               0.58
# latitude           0.00
# longitude          0.00
# id_                0.00
# year               0.00
# dtype: float64

# %% [markdown]
# ## Análisis y gestión de nulos de las categóricas

# %%
sp_eda.analisis_general_cat(df_limpio)
# Out:
# La distribucion de la columna JOB_GROUPED
# Esta columna tiene 6 valores unicos
# job_grouped
# technical         0.262290
# administrative    0.254906
# manual            0.252655
# management        0.142094
# not_working       0.088055
# Name: proportion, dtype: float64
# ______________
# count         42655
# unique            5
# top       technical
# freq          11188
# Name: job_grouped, dtype: object
# --------------
# La distribucion de la columna MARITAL
# Esta columna tiene 4 valores unicos
# marital
# married     0.605825
# single      0.282069
# divorced    0.112105
# Name: proportion, dtype: float64
# ______________
# count       42915
# unique          3
# top       married
# freq        25999
# Name: marital, dtype: object
# --------------
# La distribucion de la columna EDUCATION
# Esta columna tiene 8 valores unicos
# education
# university degree      0.308839
# high school            0.240939
# basic 9y               0.153157
# professional course    0.132959
# ...

# %%
sp_visualizacion.subplot_col_cat(df_limpio)

# %%
df_cat = df_limpio[df_limpio.select_dtypes(include="O").columns]
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   job_grouped  42655 non-null  object
#  1   marital      42915 non-null  object
#  2   education    41193 non-null  object
#  3   contact      43000 non-null  object
#  4   poutcome     43000 non-null  object
#  5   y            43000 non-null  object
#  6   date         42752 non-null  object
#  7   id_          43000 non-null  object
# dtypes: object(8)
# memory usage: 2.6+ MB

# %%
sp_eda.calcular_porcentaje_nulos(df_cat)[1]
# Out:
# job_grouped    0.80
# marital        0.20
# education      4.20
# contact        0.00
# poutcome       0.00
# y              0.00
# date           0.58
# id_            0.00
# dtype: float64

# %%
df_cat = df_cat.fillna("Unknown")
sp_eda.calcular_porcentaje_nulos(df_cat)[1]
# Out:
# job_grouped    0.0
# marital        0.0
# education      0.0
# contact        0.0
# poutcome       0.0
# y              0.0
# date           0.0
# id_            0.0
# dtype: float64

# %%
df_limpio[df_limpio.select_dtypes(include="O").columns] = df_cat
sp_eda.calcular_porcentaje_nulos(df_limpio)[1]
# Out:
# age               11.91
# job_grouped        0.00
# marital            0.00
# education          0.00
# default           20.89
# housing            2.39
# loan               2.39
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp_var_rate       0.00
# cons_price_idx     1.10
# cons_conf_idx      0.00
# euribor3m         21.53
# nr_employed        0.00
# y                  0.00
# date               0.00
# latitude           0.00
# longitude          0.00
# id_                0.00
# year               0.00
# dtype: float64
