# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../Data/data_transformacion_limpieza_bank.csv')

# %%
import sys
sys.path.append("../SRC")

import sp_limpieza_bank as sp

# %%
sp.eda_preliminar(df)
# Out:
#         age          job   marital            education  default  housing  \
# 3118   47.0  blue-collar   MARRIED             basic.4y      0.0      1.0
# 4256   35.0     services    SINGLE             basic.4y      0.0      1.0
# 4670   53.0      retired  DIVORCED          high.school      0.0      1.0
# 35831  42.0   technician   MARRIED  professional.course      0.0      0.0
# 26835  36.0       admin.  DIVORCED    university.degree      0.0      0.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 3118    0.0  telephone       106         1    999         0  NONEXISTENT
# 4256    0.0  telephone      1777         1    999         0  NONEXISTENT
# 4670    0.0  telephone       111         3    999         0  NONEXISTENT
# 35831   0.0   cellular        85         1    999         0  NONEXISTENT
# 26835   1.0   cellular        56         2    999         0  NONEXISTENT
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m nr_employed    y  \
# 3118            1.1         93,994         -36,4      4,86        5191   no
# 4256            1.1         93,994         -36,4     4,856        5191  yes
# 4670            1.1         93,994         -36,4     4,858        5191   no
# 35831          -1.8         92,893         -46,2     1,264      5099,1   no
# 26835          -0.1           93,2           -42     4,076      5195,8   no
#
#                     date  latitude  longitude  \
# 3118     28-febrero-2015    32.312    -71.140
# 4256      27-agosto-2016    36.897    -90.111
# 4670   30-diciembre-2015    34.833   -105.783
# 35831    28-febrero-2019    25.116    -70.126
# 26835      12-abril-2016    31.226    -80.427
#
#                                         id_
# 3118   04235758-ac5a-4aa5-a525-2990c444140e
# 4256   7c446747-e7ac-4dd3-9483-25f1c625c752
# 4670   59cdf745-e8b8-4455-9a2d-5a035c2df6b2
# 35831  ee1a062d-e1ec-4cde-868c-e187e391f876
# 26835  4959d84b-d3c2-4d2c-8f8e-7c8a0b39aaa3
# ----------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp_var_rate    43000 non-null  float64
#  14  cons_price_idx  42529 non-null  object
#  15  cons_conf_idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr_employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(7), int64(4), object(12)
# memory usage: 7.5+ MB
# None
# ----------------
# NULOS
# age               11.91
# job                0.80
# marital            0.20
# education          4.20
# default           20.89
# housing            2.39
# loan               2.39
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp_var_rate       0.00
# cons_price_idx     1.10
# cons_conf_idx      0.00
# euribor3m         21.53
# nr_employed        0.00
# y                  0.00
# date               0.58
# latitude           0.00
# longitude          0.00
# id_                0.00
# dtype: float64
# ----------------
# DUPLICADOS
# 0
# ----------------
# VALUE COUNTS
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ---------------------------
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# ---------------------------
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# ---------------------------
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ---------------------------
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# ---------------------------
# cons_price_idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# 93,444    5349
# 94,465    4522
# 93,2      3731
# 93,075    2552
# 92,201     803
# 92,963     742
# 92,431     471
# 92,649     375
# 94,215     320
# 94,199     316
# 92,843     298
# 92,379     274
# 93,369     271
# 94,027     242
# 94,055     236
# 93,876     224
# 94,601     212
# 92,469     184
# 92,713     179
# 93,749     179
# 94,767     130
# 93,798      48
# 92,756      11
# Name: count, dtype: int64
# ---------------------------
# cons_conf_idx
# -36,4    8020
# -42,7    7004
# -46,2    6057
# -36,1    5408
# -41,8    4568
# -42      3782
# -47,1    2581
# -31,4     815
# -40,8     748
# -26,9     477
# -30,1     379
# -40,3     328
# -37,5     318
# -50       299
# -29,8     277
# -34,8     275
# -38,3     245
# -39,8     239
# -40       225
# -49,5     214
# -33,6     185
# -34,6     183
# -33       181
# -50,8     133
# -40,4      48
# -45,9      11
# Name: count, dtype: int64
# ---------------------------
# euribor3m
# 4,857    2287
# 4,962    2124
# 4,963    2019
# 4,961    1594
# 4,964     964
#          ...
# 3,743       1
# 3,563       1
# 3,488       1
# 3,428       1
# 0,969       1
# Name: count, Length: 309, dtype: int64
# ---------------------------
# nr_employed
# 5228,1    16980
# 5099,1     8937
# 5191       8020
# 5195,8     3830
# 5076,2     1748
# 5017,5     1133
# 4991,6      812
# 5008,7      683
# 4963,6      665
# 5023,5      181
# 5176,3       11
# Name: count, dtype: int64
# ---------------------------
# y
# no     38156
# yes     4844
# Name: count, dtype: int64
# ---------------------------
# date
# 28-febrero-2018      95
# 28-febrero-2016      94
# 28-febrero-2015      92
# 28-febrero-2017      89
# 28-febrero-2019      85
#                      ..
# 2-julio-2016         11
# 14-abril-2015        10
# 20-noviembre-2015    10
# 4-abril-2017         10
# 21-diciembre-2019    10
# Name: count, Length: 1825, dtype: int64
# ---------------------------
# id_
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# c25b5d31-bb7e-41af-898d-42bf3e479351    1
# bfd6bad9-f23a-445a-838e-10ee90110534    1
# 075b0e72-b5e3-43f4-90cd-29f9090b2b1a    1
# 482a2d86-c9f0-46b7-9f6f-82c769690d48    1
#                                        ..
# 27e317a2-722c-454d-850b-97b536029c81    1
# 6d9c117f-af67-4a89-83db-caf514a42374    1
# 6a229b87-6bf9-4339-9639-b98555df71e7    1
# cc891cf7-206c-47f0-804f-20b5b757d5fc    1
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# Name: count, Length: 43000, dtype: int64
# ---------------------------

# %%
job_mapping = {
    'admin.': 'administrative',
    'blue-collar' : 'manual',
    'housemaid' : 'manual',
    'technician' : 'technical',
    'services' : 'technical',
    'management' : 'management',
    'entrepreneur' : 'management',
    'self-employed' : 'management',
    'retired' : 'not_working',
    'unemployed' : 'not_working',
    'student' : 'not_working'
}

df['job_grouped'] = df['job'].map(job_mapping) # agrupamos los diferentes trabajos por categorías porque tiene muchos valores con poca frecuencia.

# %%
cols = df.columns.tolist()
cols.insert(cols.index('job') + 1, cols.pop(cols.index('job_grouped'))) # movemos 'job_grouped' justo después de 'job'
df = df[cols]

# %%
df.drop(columns='job', inplace=True) # eliminamos la columna 'job' ya que hemos creado la nueva que lo agrupa por categorías en 'job_grouped'

# %%
sp.valores_minus(df)

# %%
df['age'] = df['age'].astype('Int64')

# %%
quitar_coma = ['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']

sp.cambiar_coma(df,quitar_coma)

# %%
gestion_nulos = ['cons_price_idx', 'euribor3m', 'nr_employed']

sp.valor_cero(df, gestion_nulos)

print(df[gestion_nulos].isna().sum())
# Out:
# cons_price_idx    0
# euribor3m         0
# nr_employed       0
# dtype: int64

# %%
cambiar_type = ['cons_price_idx', 'euribor3m', 'nr_employed']

sp.convertir_float(df, cambiar_type)

print(df[cambiar_type].dtypes)
# Out:
# cons_price_idx    float64
# euribor3m         float64
# nr_employed       float64
# dtype: object

# %%
redondear_decimal = ['cons_price_idx', 'euribor3m']

sp.round_decimal(df,redondear_decimal)

# %%
df['nr_employed'] = df['nr_employed'].round(0).astype(int)

# %%
df['education'] = df['education'].replace({
    'university.degree': 'university degree',
    'high.school': 'high school',
    'basic.9y': 'basic 9y',
    'professional.course': 'professional course',
    'basic.4y': 'basic 4y',
    'basic.6y': 'basic 6y'
})

# %%
import locale

locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')

df['date'] = pd.to_datetime(df['date'], format="%d-%B-%Y")

df['year'] = df['date'].dt.year

df['year'] = df['year'].fillna(0).astype(int)

# %%
df.sample(5)
# Out:
#         age     job_grouped  marital          education  default  housing  \
# 4834     24     not_working   single  university degree      0.0      0.0
# 36766  <NA>  administrative   single  university degree      0.0      1.0
# 22744    33  administrative  married  university degree      0.0      0.0
# 24977  <NA>          manual  married           basic 4y      NaN      0.0
# 691      36  administrative  married  university degree      0.0      1.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 4834    0.0  telephone        96         2    999         0  nonexistent
# 36766   0.0  telephone        42         1    999         0  nonexistent
# 22744   0.0   cellular       177         2    999         0  nonexistent
# 24977   0.0   cellular       103         1    999         0  nonexistent
# 691     0.0  telephone       166         3    999         0  nonexistent
#
#        emp_var_rate  cons_price_idx cons_conf_idx  euribor3m  nr_employed   y  \
# 4834            1.1            94.0         -36.4        4.9         5191  no
# 36766          -2.9            93.0         -40.8        1.1         5076  no
# 22744           1.4            93.4         -36.1        NaN         5228  no
# 24977          -0.1            93.2           -42        4.2         5196  no
# 691             1.1            94.0         -36.4        4.9         5191  no
#
#             date  latitude  longitude                                   id_  \
# 4834  2015-12-26    25.200    -99.256  a6678585-4179-451b-b6f5-b28851840635
# 36766 2016-09-05    47.533    -79.723  c54941dd-5809-43ec-aa21-3b2e2e75c631
# 22744 2019-08-06    30.291   -100.067  821ff5c5-57fb-4477-a712-7c13dafb4625
# 24977 2018-05-04    33.129    -97.271  5c55c0fa-c762-4f4f-9631-de7b05a66c98
# 691   2018-07-09    47.688   -116.145  c990d7b3-b422-4f46-becf-1020aeb793c4
#
#        year
# 4834   2015
# 36766  2016
# 22744  2019
# 24977  2018
# 691    2018

# %%
df.to_csv('../Data/data_limpios_bank.csv', index=False)
