# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../Data/data_transformacion_limpieza.csv')

# %%
import sys
sys.path.append("..")

from SRC import sp_limpieza as sp

# %%
sp.eda_preliminar(df)
# Out:
#         age           job  marital            education  default  housing  \
# 36343  39.0        admin.  MARRIED    university.degree      0.0      0.0
# 11408  36.0      services  MARRIED          high.school      0.0      0.0
# 2370   35.0       student   SINGLE    university.degree      NaN      0.0
# 14910  34.0  entrepreneur  MARRIED  professional.course      0.0      1.0
# 12513  49.0   blue-collar  MARRIED                  NaN      NaN      NaN
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 36343   0.0   cellular      2219         1    999         1      FAILURE
# 11408   0.0  telephone       166         1    999         0  NONEXISTENT
# 2370    0.0  telephone       443         1    999         0  NONEXISTENT
# 14910   0.0   cellular        94         2    999         0  NONEXISTENT
# 12513   NaN   cellular       375         3    999         0  NONEXISTENT
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m nr_employed   y  \
# 36343          -2.9         92,963         -40,8       NaN      5076,2  no
# 11408           1.4         94,465         -41,8     4,959      5228,1  no
# 2370            1.1         93,994         -36,4       NaN        5191  no
# 14910           1.4         93,918         -42,7     4,958      5228,1  no
# 12513           1.4         93,918         -42,7      4,96      5228,1  no
#
#                   date  latitude  longitude  \
# 36343   29-agosto-2017    46.904   -119.444
# 11408   17-agosto-2016    25.619   -121.753
# 2370     21-junio-2016    33.191    -93.327
# 14910     4-marzo-2017    47.088   -111.729
# 12513  24-febrero-2016    28.450    -97.548
#
#                                         id_
# 36343  7c8ca62e-da1f-47ef-86c8-b136b99f94c1
# 11408  32190883-ad6c-41b6-b39e-94ccae09801a
# 2370   277e77fa-0351-45bf-9b40-470d688560e3
# 14910  b4fe50fe-bc48-4173-b426-893160febce3
# 12513  ac192391-d6d7-4dc9-89bc-d6d89501f116
# ----------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp_var_rate    43000 non-null  float64
#  14  cons_price_idx  42529 non-null  object
#  15  cons_conf_idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr_employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(7), int64(4), object(12)
# memory usage: 7.5+ MB
# None
# ----------------
# NULOS
# age               11.91
# job                0.80
# marital            0.20
# education          4.20
# default           20.89
# housing            2.39
# loan               2.39
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp_var_rate       0.00
# cons_price_idx     1.10
# cons_conf_idx      0.00
# euribor3m         21.53
# nr_employed        0.00
# y                  0.00
# date               0.58
# latitude           0.00
# longitude          0.00
# id_                0.00
# dtype: float64
# ----------------
# DUPLICADOS
# 0
# ----------------
# VALUE COUNTS
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ---------------------------
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# ---------------------------
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# ---------------------------
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ---------------------------
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# ---------------------------
# cons_price_idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# 93,444    5349
# 94,465    4522
# 93,2      3731
# 93,075    2552
# 92,201     803
# 92,963     742
# 92,431     471
# 92,649     375
# 94,215     320
# 94,199     316
# 92,843     298
# 92,379     274
# 93,369     271
# 94,027     242
# 94,055     236
# 93,876     224
# 94,601     212
# 92,469     184
# 92,713     179
# 93,749     179
# 94,767     130
# 93,798      48
# 92,756      11
# Name: count, dtype: int64
# ---------------------------
# cons_conf_idx
# -36,4    8020
# -42,7    7004
# -46,2    6057
# -36,1    5408
# -41,8    4568
# -42      3782
# -47,1    2581
# -31,4     815
# -40,8     748
# -26,9     477
# -30,1     379
# -40,3     328
# -37,5     318
# -50       299
# -29,8     277
# -34,8     275
# -38,3     245
# -39,8     239
# -40       225
# -49,5     214
# -33,6     185
# -34,6     183
# -33       181
# -50,8     133
# -40,4      48
# -45,9      11
# Name: count, dtype: int64
# ---------------------------
# euribor3m
# 4,857    2287
# 4,962    2124
# 4,963    2019
# 4,961    1594
# 4,964     964
#          ...
# 3,743       1
# 3,563       1
# 3,488       1
# 3,428       1
# 0,969       1
# Name: count, Length: 309, dtype: int64
# ---------------------------
# nr_employed
# 5228,1    16980
# 5099,1     8937
# 5191       8020
# 5195,8     3830
# 5076,2     1748
# 5017,5     1133
# 4991,6      812
# 5008,7      683
# 4963,6      665
# 5023,5      181
# 5176,3       11
# Name: count, dtype: int64
# ---------------------------
# y
# no     38156
# yes     4844
# Name: count, dtype: int64
# ---------------------------
# date
# 28-febrero-2018      95
# 28-febrero-2016      94
# 28-febrero-2015      92
# 28-febrero-2017      89
# 28-febrero-2019      85
#                      ..
# 2-julio-2016         11
# 14-abril-2015        10
# 20-noviembre-2015    10
# 4-abril-2017         10
# 21-diciembre-2019    10
# Name: count, Length: 1825, dtype: int64
# ---------------------------
# id_
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# c25b5d31-bb7e-41af-898d-42bf3e479351    1
# bfd6bad9-f23a-445a-838e-10ee90110534    1
# 075b0e72-b5e3-43f4-90cd-29f9090b2b1a    1
# 482a2d86-c9f0-46b7-9f6f-82c769690d48    1
#                                        ..
# 27e317a2-722c-454d-850b-97b536029c81    1
# 6d9c117f-af67-4a89-83db-caf514a42374    1
# 6a229b87-6bf9-4339-9639-b98555df71e7    1
# cc891cf7-206c-47f0-804f-20b5b757d5fc    1
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# Name: count, Length: 43000, dtype: int64
# ---------------------------

# %%
job_mapping = {
    'admin.': 'administrative',
    'blue-collar' : 'manual',
    'housemaid' : 'manual',
    'technician' : 'technical',
    'services' : 'technical',
    'management' : 'management',
    'entrepreneur' : 'management',
    'self-employed' : 'management',
    'retired' : 'not_working',
    'unemployed' : 'not_working',
    'student' : 'not_working'
}

df['job_grouped'] = df['job'].map(job_mapping) # agrupamos los diferentes trabajos por categorías porque tiene muchos valores con poca frecuencia.

# %%
cols = df.columns.tolist()
cols.insert(cols.index('job') + 1, cols.pop(cols.index('job_grouped'))) # movemos 'job_grouped' justo después de 'job'
df = df[cols]

# %%
df.drop(columns='job', inplace=True) # eliminamos la columna 'job' ya que hemos creado la nueva que lo agrupa por categorías en 'job_grouped'

# %%
sp.valores_minus(df)

# %%
df.sample(5)
# Out:
#         age     job_grouped  marital            education  default  housing  \
# 16507   NaN       technical   single  professional.course      0.0      0.0
# 14608  33.0          manual  married          high.school      NaN      1.0
# 40061  64.0  administrative  married          high.school      0.0      0.0
# 2560   41.0          manual   single             basic.9y      NaN      0.0
# 13668   NaN      management  married                  NaN      0.0      0.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 16507   0.0  telephone       296         2    999         0  nonexistent
# 14608   0.0   cellular       624         6    999         0  nonexistent
# 40061   0.0   cellular       368         1    999         0  nonexistent
# 2560    0.0  telephone       194         4    999         0  nonexistent
# 13668   0.0   cellular       114         1    999         0  nonexistent
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m nr_employed    y  \
# 16507           1.4         93,918         -42,7     4,963      5228,1   no
# 14608           1.4         93,918         -42,7     4,961      5228,1   no
# 40061          -1.7         94,215         -40,3     0,884      4991,6  yes
# 2560            1.1         93,994         -36,4     4,859        5191   no
# 13668           1.4         93,918         -42,7     4,963      5228,1   no
#
#                     date  latitude  longitude  \
# 16507     9-octubre-2019    35.197    -86.451
# 14608  15-diciembre-2019    30.719    -78.915
# 40061      14-enero-2015    45.871    -89.703
# 2560     23-octubre-2015    44.335    -83.768
# 13668       18-mayo-2019    29.505    -90.939
#
#                                         id_
# 16507  2b4c6e79-2117-4094-8649-cf388233ee02
# 14608  ddf1d560-8987-4612-8d18-00167d3643cb
# 40061  1b692041-4f04-4dda-b26a-8089b02aac84
# 2560   3b00e5aa-8947-4647-b610-dd3132c52d84
# 13668  eee7a944-3cba-49b5-baf3-af06dfbc12bc
