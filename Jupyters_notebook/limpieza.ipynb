# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../Data/data_transformacion_limpieza.csv')

# %%
import sys
sys.path.append("..")

from SRC import sp_limpieza as sp

# %%
sp.eda_preliminar(df)
# Out:
#         age         job  marital          education  default  housing  loan  \
# 40267  47.0  management  MARRIED  university.degree      0.0      1.0   0.0
# 14457  33.0   housemaid  MARRIED           basic.9y      0.0      0.0   0.0
# 11227  42.0  management  MARRIED  university.degree      0.0      0.0   0.0
# 17348  57.0     retired  MARRIED           basic.4y      NaN      0.0   1.0
# 7549   35.0  technician  MARRIED           basic.6y      0.0      0.0   0.0
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 40267   cellular       145         3      3         2      SUCCESS
# 14457   cellular       860         4    999         0  NONEXISTENT
# 11227  telephone        92         2    999         0  NONEXISTENT
# 17348   cellular        65         5    999         0  NONEXISTENT
# 7549   telephone       107         3    999         0  NONEXISTENT
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m nr_employed    y  \
# 40267          -1.7         94,027         -38,3     0,904      4991,6   no
# 14457           1.4         93,918         -42,7     4,961      5228,1  yes
# 11227           1.4         94,465         -41,8     4,961      5228,1   no
# 17348           1.4         93,918         -42,7     4,962      5228,1   no
# 7549            1.1         93,994         -36,4     4,864        5191   no
#
#                      date  latitude  longitude  \
# 40267       24-julio-2018    42.632    -89.130
# 14457       19-abril-2015    28.848   -110.351
# 11227  21-septiembre-2016    36.422    -92.682
# 17348       19-julio-2019    46.653    -84.223
# 7549    27-noviembre-2015    36.080   -105.239
#
#                                         id_
# 40267  fa62e5a7-6a75-4822-b56e-cd02abd6fbdc
# 14457  13b15dac-9dac-4ef7-9272-ff73789bec72
# 11227  c7d2f98d-87a7-47d9-8b83-89e9a1cdd7e2
# 17348  81326775-d44d-44cf-bcd5-f3e00bd91cfe
# 7549   09f5cf83-4d27-45a6-8830-c7562e05fa62
# ----------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp_var_rate    43000 non-null  float64
#  14  cons_price_idx  42529 non-null  object
#  15  cons_conf_idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr_employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(7), int64(4), object(12)
# memory usage: 7.5+ MB
# None
# ----------------
# NULOS
# age               11.91
# job                0.80
# marital            0.20
# education          4.20
# default           20.89
# housing            2.39
# loan               2.39
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp_var_rate       0.00
# cons_price_idx     1.10
# cons_conf_idx      0.00
# euribor3m         21.53
# nr_employed        0.00
# y                  0.00
# date               0.58
# latitude           0.00
# longitude          0.00
# id_                0.00
# dtype: float64
# ----------------
# DUPLICADOS
# 0
# ----------------
# VALUE COUNTS
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ---------------------------
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# ---------------------------
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# ---------------------------
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ---------------------------
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# ---------------------------
# cons_price_idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# 93,444    5349
# 94,465    4522
# 93,2      3731
# 93,075    2552
# 92,201     803
# 92,963     742
# 92,431     471
# 92,649     375
# 94,215     320
# 94,199     316
# 92,843     298
# 92,379     274
# 93,369     271
# 94,027     242
# 94,055     236
# 93,876     224
# 94,601     212
# 92,469     184
# 92,713     179
# 93,749     179
# 94,767     130
# 93,798      48
# 92,756      11
# Name: count, dtype: int64
# ---------------------------
# cons_conf_idx
# -36,4    8020
# -42,7    7004
# -46,2    6057
# -36,1    5408
# -41,8    4568
# -42      3782
# -47,1    2581
# -31,4     815
# -40,8     748
# -26,9     477
# -30,1     379
# -40,3     328
# -37,5     318
# -50       299
# -29,8     277
# -34,8     275
# -38,3     245
# -39,8     239
# -40       225
# -49,5     214
# -33,6     185
# -34,6     183
# -33       181
# -50,8     133
# -40,4      48
# -45,9      11
# Name: count, dtype: int64
# ---------------------------
# euribor3m
# 4,857    2287
# 4,962    2124
# 4,963    2019
# 4,961    1594
# 4,964     964
#          ...
# 3,743       1
# 3,563       1
# 3,488       1
# 3,428       1
# 0,969       1
# Name: count, Length: 309, dtype: int64
# ---------------------------
# nr_employed
# 5228,1    16980
# 5099,1     8937
# 5191       8020
# 5195,8     3830
# 5076,2     1748
# 5017,5     1133
# 4991,6      812
# 5008,7      683
# 4963,6      665
# 5023,5      181
# 5176,3       11
# Name: count, dtype: int64
# ---------------------------
# y
# no     38156
# yes     4844
# Name: count, dtype: int64
# ---------------------------
# date
# 28-febrero-2018      95
# 28-febrero-2016      94
# 28-febrero-2015      92
# 28-febrero-2017      89
# 28-febrero-2019      85
#                      ..
# 2-julio-2016         11
# 14-abril-2015        10
# 20-noviembre-2015    10
# 4-abril-2017         10
# 21-diciembre-2019    10
# Name: count, Length: 1825, dtype: int64
# ---------------------------
# id_
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# c25b5d31-bb7e-41af-898d-42bf3e479351    1
# bfd6bad9-f23a-445a-838e-10ee90110534    1
# 075b0e72-b5e3-43f4-90cd-29f9090b2b1a    1
# 482a2d86-c9f0-46b7-9f6f-82c769690d48    1
#                                        ..
# 27e317a2-722c-454d-850b-97b536029c81    1
# 6d9c117f-af67-4a89-83db-caf514a42374    1
# 6a229b87-6bf9-4339-9639-b98555df71e7    1
# cc891cf7-206c-47f0-804f-20b5b757d5fc    1
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# Name: count, Length: 43000, dtype: int64
# ---------------------------

# %%
job_mapping = {
    'admin.': 'administrative',
    'blue-collar' : 'manual',
    'housemaid' : 'manual',
    'technician' : 'technical',
    'services' : 'technical',
    'management' : 'management',
    'entrepreneur' : 'management',
    'self-employed' : 'management',
    'retired' : 'not_working',
    'unemployed' : 'not_working',
    'student' : 'not_working'
}

df['job_grouped'] = df['job'].map(job_mapping) # agrupamos los diferentes trabajos por categorías porque tiene muchos valores con poca frecuencia.

# %%
cols = df.columns.tolist()
cols.insert(cols.index('job') + 1, cols.pop(cols.index('job_grouped'))) # movemos 'job_grouped' justo después de 'job'
df = df[cols]

# %%
df.drop(columns='job', inplace=True) # eliminamos la columna 'job' ya que hemos creado la nueva que lo agrupa por categorías en 'job_grouped'

# %%
sp.valores_minus(df)

# %%
df['age'] = df['age'].astype('Int64')

# %%
quitar_coma = ['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']

sp.cambiar_coma(df,quitar_coma)

# %%
nulos_valor_cero = ['cons_price_idx', 'euribor3m', 'nr_employed']

sp.valor_cero(df, nulos_valor_cero)

print(df[nulos_valor_cero].isna().sum())
# Out:
# cons_price_idx    0
# euribor3m         0
# nr_employed       0
# dtype: int64

# %%
cambiar_type = ['cons_price_idx', 'euribor3m', 'nr_employed']

sp.convertir_float(df, cambiar_type)

print(df[cambiar_type].dtypes)
# Out:
# cons_price_idx    float64
# euribor3m         float64
# nr_employed       float64
# dtype: object

# %%
redondear_decimal = ['cons_price_idx', 'euribor3m']

sp.round_decimal(df,redondear_decimal)

# %%
df['nr_employed'] = df['nr_employed'].round(0).astype(int)

# %%
df['education'] = df['education'].replace({
    'university.degree': 'university degree',
    'high.school': 'high school',
    'basic.9y': 'basic 9y',
    'professional.course': 'professional course',
    'basic.4y': 'basic 4y',
    'basic.6y': 'basic 6y'
})

# %%
df.sample(5)
# Out:
#        age     job_grouped  marital            education  default  housing  \
# 12017   33      management  married  professional course      0.0      1.0
# 33873   34  administrative  married             basic 6y      0.0      1.0
# 17363   51       technical  married          high school      NaN      1.0
# 4419    37       technical  married  professional course      0.0      1.0
# 40609   48          manual  married             basic 4y      0.0      1.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 12017   0.0  telephone       141         4    999         0  nonexistent
# 33873   0.0   cellular       298         2    999         0  nonexistent
# 17363   0.0  telephone       596         3    999         0  nonexistent
# 4419    0.0  telephone       657         1    999         0  nonexistent
# 40609   0.0  telephone         9         1    999         0  nonexistent
#
#        emp_var_rate  cons_price_idx cons_conf_idx  euribor3m  nr_employed  \
# 12017           1.4            94.5         -41.8        4.9         5228
# 33873          -1.8            92.9         -46.2        1.3         5099
# 17363           1.4            93.9         -42.7        5.0         5228
# 4419            1.1            94.0         -36.4        4.9         5191
# 40609          -1.1            94.2         -37.5        0.9         4964
#
#          y                date  latitude  longitude  \
# 12017   no        7-enero-2017    26.152   -113.266
# 33873   no  13-septiembre-2019    46.202   -101.906
# 17363  yes       30-junio-2016    40.044    -72.606
# 4419    no      15-agosto-2019    37.246    -81.252
# 40609   no      4-febrero-2015    27.761    -72.856
#
#                                         id_
# 12017  58694389-802b-4ec0-9f9a-355f8b69999d
# 33873  0227c7a0-b563-4705-bb54-6b30d5e60e0b
# 17363  d5c814ab-1b76-4620-8b4a-82267cada2c4
# 4419   72a669f2-9478-490e-96b6-e1d22cb07fe6
# 40609  a1acf525-7199-4484-b357-3ba7211b834c
