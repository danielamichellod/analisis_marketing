# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../Data/data_transformacion_limpieza.csv')

# %%
import sys
sys.path.append("..")

from SRC import sp_limpieza as sp

# %%
sp.eda_preliminar(df)
# Out:
#         age            job  marital          education  default  housing  \
# 3037    NaN    blue-collar   SINGLE        high.school      0.0      1.0
# 27890  33.0      housemaid      NaN  university.degree      0.0      1.0
# 6966   51.0  self-employed  MARRIED           basic.9y      0.0      1.0
# 25585  44.0         admin.   SINGLE  university.degree      0.0      1.0
# 2199   40.0    blue-collar  MARRIED           basic.6y      NaN      0.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 3037    0.0  telephone       182         2    999         0  NONEXISTENT
# 27890   0.0   cellular        80         1    999         0  NONEXISTENT
# 6966    0.0  telephone       162         2    999         0  NONEXISTENT
# 25585   0.0   cellular       132         1    999         0  NONEXISTENT
# 2199    0.0  telephone       120         1    999         0  NONEXISTENT
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m nr_employed   y  \
# 3037            1.1         93,994         -36,4      4,86        5191  no
# 27890          -1.8         93,075         -47,1     1,483      5099,1  no
# 6966            1.1         93,994         -36,4      4,86        5191  no
# 25585          -0.1           93,2           -42      4,12      5195,8  no
# 2199            1.1         93,994         -36,4     4,856        5191  no
#
#                      date  latitude  longitude  \
# 3037   13-septiembre-2017    48.935   -114.042
# 27890   26-noviembre-2019    43.620   -113.595
# 6966        11-enero-2017    39.381   -118.548
# 25585       4-agosto-2018    38.929    -94.680
# 2199       23-agosto-2019    37.463   -107.137
#
#                                         id_
# 3037   6b8af17c-5da4-4ebe-93d9-bf18a52f7091
# 27890  19bd304b-940e-4933-9687-b8e91a22af32
# 6966   86d51b68-6b3b-408d-849e-a6afbb2f057e
# 25585  eb52b743-0d3f-4e6c-bf8e-8a8dfbd44936
# 2199   441ea2a6-a1f6-4f43-b505-3b10791a43b2
# ----------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp_var_rate    43000 non-null  float64
#  14  cons_price_idx  42529 non-null  object
#  15  cons_conf_idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr_employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(7), int64(4), object(12)
# memory usage: 7.5+ MB
# None
# ----------------
# NULOS
# age               11.91
# job                0.80
# marital            0.20
# education          4.20
# default           20.89
# housing            2.39
# loan               2.39
# contact            0.00
# duration           0.00
# campaign           0.00
# pdays              0.00
# previous           0.00
# poutcome           0.00
# emp_var_rate       0.00
# cons_price_idx     1.10
# cons_conf_idx      0.00
# euribor3m         21.53
# nr_employed        0.00
# y                  0.00
# date               0.58
# latitude           0.00
# longitude          0.00
# id_                0.00
# dtype: float64
# ----------------
# DUPLICADOS
# 0
# ----------------
# VALUE COUNTS
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ---------------------------
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# ---------------------------
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# ---------------------------
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ---------------------------
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# ---------------------------
# cons_price_idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# 93,444    5349
# 94,465    4522
# 93,2      3731
# 93,075    2552
# 92,201     803
# 92,963     742
# 92,431     471
# 92,649     375
# 94,215     320
# 94,199     316
# 92,843     298
# 92,379     274
# 93,369     271
# 94,027     242
# 94,055     236
# 93,876     224
# 94,601     212
# 92,469     184
# 92,713     179
# 93,749     179
# 94,767     130
# 93,798      48
# 92,756      11
# Name: count, dtype: int64
# ---------------------------
# cons_conf_idx
# -36,4    8020
# -42,7    7004
# -46,2    6057
# -36,1    5408
# -41,8    4568
# -42      3782
# -47,1    2581
# -31,4     815
# -40,8     748
# -26,9     477
# -30,1     379
# -40,3     328
# -37,5     318
# -50       299
# -29,8     277
# -34,8     275
# -38,3     245
# -39,8     239
# -40       225
# -49,5     214
# -33,6     185
# -34,6     183
# -33       181
# -50,8     133
# -40,4      48
# -45,9      11
# Name: count, dtype: int64
# ---------------------------
# euribor3m
# 4,857    2287
# 4,962    2124
# 4,963    2019
# 4,961    1594
# 4,964     964
#          ...
# 3,743       1
# 3,563       1
# 3,488       1
# 3,428       1
# 0,969       1
# Name: count, Length: 309, dtype: int64
# ---------------------------
# nr_employed
# 5228,1    16980
# 5099,1     8937
# 5191       8020
# 5195,8     3830
# 5076,2     1748
# 5017,5     1133
# 4991,6      812
# 5008,7      683
# 4963,6      665
# 5023,5      181
# 5176,3       11
# Name: count, dtype: int64
# ---------------------------
# y
# no     38156
# yes     4844
# Name: count, dtype: int64
# ---------------------------
# date
# 28-febrero-2018      95
# 28-febrero-2016      94
# 28-febrero-2015      92
# 28-febrero-2017      89
# 28-febrero-2019      85
#                      ..
# 2-julio-2016         11
# 14-abril-2015        10
# 20-noviembre-2015    10
# 4-abril-2017         10
# 21-diciembre-2019    10
# Name: count, Length: 1825, dtype: int64
# ---------------------------
# id_
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# c25b5d31-bb7e-41af-898d-42bf3e479351    1
# bfd6bad9-f23a-445a-838e-10ee90110534    1
# 075b0e72-b5e3-43f4-90cd-29f9090b2b1a    1
# 482a2d86-c9f0-46b7-9f6f-82c769690d48    1
#                                        ..
# 27e317a2-722c-454d-850b-97b536029c81    1
# 6d9c117f-af67-4a89-83db-caf514a42374    1
# 6a229b87-6bf9-4339-9639-b98555df71e7    1
# cc891cf7-206c-47f0-804f-20b5b757d5fc    1
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# Name: count, Length: 43000, dtype: int64
# ---------------------------

# %%
job_mapping = {
    'admin.': 'administrative',
    'blue-collar' : 'manual',
    'housemaid' : 'manual',
    'technician' : 'technical',
    'services' : 'technical',
    'management' : 'management',
    'entrepreneur' : 'management',
    'self-employed' : 'management',
    'retired' : 'not_working',
    'unemployed' : 'not_working',
    'student' : 'not_working'
}

df['job_grouped'] = df['job'].map(job_mapping) # agrupamos los diferentes trabajos por categorías porque tiene muchos valores con poca frecuencia.

# %%
cols = df.columns.tolist()
cols.insert(cols.index('job') + 1, cols.pop(cols.index('job_grouped'))) # movemos 'job_grouped' justo después de 'job'
df = df[cols]

# %%
df.drop(columns='job', inplace=True) # eliminamos la columna 'job' ya que hemos creado la nueva que lo agrupa por categorías en 'job_grouped'

# %%
sp.valores_minus(df)

# %%
df['age'] = df['age'].astype('Int64')

# %%
quitar_coma = ['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']

sp.cambiar_coma(df,quitar_coma)

# %%
gestion_nulos = ['cons_price_idx', 'euribor3m', 'nr_employed']

sp.valor_cero(df, gestion_nulos)

print(df[gestion_nulos].isna().sum())
# Out:
# cons_price_idx    0
# euribor3m         0
# nr_employed       0
# dtype: int64

# %%
cambiar_type = ['cons_price_idx', 'euribor3m', 'nr_employed']

sp.convertir_float(df, cambiar_type)

print(df[cambiar_type].dtypes)
# Out:
# cons_price_idx    float64
# euribor3m         float64
# nr_employed       float64
# dtype: object

# %%
redondear_decimal = ['cons_price_idx', 'euribor3m']

sp.round_decimal(df,redondear_decimal)

# %%
df['nr_employed'] = df['nr_employed'].round(0).astype(int)

# %%
df['education'] = df['education'].replace({
    'university.degree': 'university degree',
    'high.school': 'high school',
    'basic.9y': 'basic 9y',
    'professional.course': 'professional course',
    'basic.4y': 'basic 4y',
    'basic.6y': 'basic 6y'
})

# %%
import locale

locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')

df['date'] = pd.to_datetime(df['date'], format="%d-%B-%Y")

df['year'] = df['date'].dt.year

df['year'] = df['year'].fillna(0).astype(int)

# %%
df.sample(5)
# Out:
#         age     job_grouped   marital          education  default  housing  \
# 31782  <NA>          manual   married           basic 6y      0.0      0.0
# 22748  <NA>     not_working   married           basic 9y      0.0      1.0
# 19926    52     not_working   married        high school      0.0      1.0
# 22707    35      management  divorced  university degree      0.0      0.0
# 1838     36  administrative   married        high school      0.0      1.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 31782   0.0   cellular       212         2    999         0  nonexistent
# 22748   0.0   cellular        93         6    999         0  nonexistent
# 19926   0.0   cellular       293         3    999         0  nonexistent
# 22707   0.0   cellular       472         3    999         0  nonexistent
# 1838    0.0  telephone        31         3    999         0  nonexistent
#
#        emp_var_rate  cons_price_idx cons_conf_idx  euribor3m  nr_employed  \
# 31782          -1.8            92.9         -46.2        NaN         5099
# 22748           1.4            93.4         -36.1        5.0         5228
# 19926           1.4            93.4         -36.1        5.0         5228
# 22707           1.4            93.4         -36.1        5.0         5228
# 1838            1.1            94.0         -36.4        4.9         5191
#
#          y       date  latitude  longitude  \
# 31782   no 2015-05-13    31.072   -110.844
# 22748   no 2019-05-25    29.163   -109.044
# 19926   no 2015-01-11    26.414    -86.330
# 22707  yes 2016-04-22    34.654    -94.750
# 1838    no 2019-12-16    37.079    -96.558
#
#                                         id_  year
# 31782  cb7a6fe8-b619-4352-a565-f0a94ca651a5  2015
# 22748  3dcfdb0f-72a9-4d88-bede-2452a9a8be00  2019
# 19926  5e272a39-aea3-4186-857c-90def203b077  2015
# 22707  b700894c-cee3-43dc-90c9-bb2a5f2ba58c  2016
# 1838   ea537518-4c2e-4ff9-af66-914ebb33ea0b  2019

# %%
df.to_csv('../Data/data_limpios.csv', index=False)
