# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# Looking in indexes: https://pypi.python.org/simple, https://pypi.apple.com/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.python.org/simple, https://pypi.apple.com/simple
# ...

# %%
xls = pd.ExcelFile('/Users/daniela/Desktop/Proyecto EDA/analisis_marketing/DataRaw/DatosProyecto/customer-details.xlsx')
print(xls.sheet_names)
# Out:
# ['2012', '2013', '2014']

# %%
file_path = '/Users/daniela/Desktop/Proyecto EDA/analisis_marketing/DataRaw/DatosProyecto/customer-details.xlsx'

sheets = pd.read_excel(file_path, sheet_name=None)

dfs = []

for sheet_name, df in sheets.items():
    df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])
    df['Join_Year'] = df['Dt_Customer'].dt.year
    dfs.append(df)
    
df_combined = pd.concat(dfs, ignore_index=True)
df_combined.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0  161770        1         0  2012-04-04                 29
# 1           1   85477        1         1  2012-12-30                  7
# 2           2  147233        1         1  2012-02-02                  5
# 3           3  121393        1         2  2012-12-21                 29
# 4           4   63164        1         2  2012-06-20                 20
#
#                                      ID  Join_Year
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079       2012
# 1  e9d37224-cb6f-4942-98d7-46672963d097       2012
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b       2012
# 3  9991fafb-4447-451a-8be2-b0df6098d13e       2012
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb       2012

# %%
df_combined.shape
# Out:
# (43170, 8)

# %%
df_combined.columns
# Out:
# Index(['Unnamed: 0', 'Income', 'Kidhome', 'Teenhome', 'Dt_Customer',
#        'NumWebVisitsMonth', 'ID', 'Join_Year'],
#       dtype='object')

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         43170 non-null  int64
#  1   Income             43170 non-null  int64
#  2   Kidhome            43170 non-null  int64
#  3   Teenhome           43170 non-null  int64
#  4   Dt_Customer        43170 non-null  datetime64[ns]
#  5   NumWebVisitsMonth  43170 non-null  int64
#  6   ID                 43170 non-null  object
#  7   Join_Year          43170 non-null  int32
# dtypes: datetime64[ns](1), int32(1), int64(5), object(1)
# memory usage: 2.5+ MB

# %%
df = df_combined.copy()

# %%
df.drop(columns="Unnamed: 0", inplace=True)
df.head()
# Out:
#    Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0  161770        1         0  2012-04-04                 29
# 1   85477        1         1  2012-12-30                  7
# 2  147233        1         1  2012-02-02                  5
# 3  121393        1         2  2012-12-21                 29
# 4   63164        1         2  2012-06-20                 20
#
#                                      ID  Join_Year
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079       2012
# 1  e9d37224-cb6f-4942-98d7-46672963d097       2012
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b       2012
# 3  9991fafb-4447-451a-8be2-b0df6098d13e       2012
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb       2012

# %%
df.to_csv('../Data/data_transformacion_limpieza_customer.csv', index=False)
