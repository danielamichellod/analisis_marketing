# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../Data/data_transformacion_limpieza_customer.csv')

# %%
import sys
sys.path.append("../SRC")

import sp_limpieza_customer as sp

# %%
sp.eda_preliminar(df)
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 10800    8521        1         2  2012-12-07                 27
# 4520    48379        1         1  2012-10-12                 22
# 25469   59164        1         2  2013-05-05                 22
# 6343    89841        2         0  2012-10-15                  8
# 20137   35680        0         1  2013-04-28                 19
#
#                                          ID  Join_Year
# 10800  4e2da5aa-2528-45aa-b8fc-085cbe875595       2012
# 4520   52fb829c-4c82-4c46-8286-5e268f169eb1       2012
# 25469  00665d1e-171b-44b0-b0de-47493a4aa0b4       2013
# 6343   8ccf0b0f-1fae-4ba6-bb51-c8633295b1f7       2012
# 20137  b2538d03-ef7d-44a3-bd48-95b24a704f7c       2013
# ----------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
# ...

# %%
df.rename(columns={
    'Kidhome': 'Kid_Home',
    'Teenhome': 'Teen_Home',
    'NumWebVisitsMonth': 'Num_Web_Visits_Month'
}, inplace=True)

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# %%
df.sample(5)
# Out:
#        Income  Kid_Home  Teen_Home Dt_Customer  Num_Web_Visits_Month  \
# 12153   42711         0          2  2012-02-27                    11
# 12172   27611         2          0  2012-09-16                    23
# 8997    53182         1          2  2012-06-09                    19
# 37930  152744         1          0  2014-02-09                    25
# 11285  148013         1          1  2012-09-04                    32
#
#                                          ID  Join_Year
# 12153  8eb63930-6e51-45a4-95f4-72bdbd5ae44f       2012
# 12172  1ff36b7d-e141-4723-8774-7598cedad5b1       2012
# 8997   3aa845c7-8f1e-4edd-be02-86700b757120       2012
# 37930  38f2c326-0445-490e-8042-f1d2a0780a52       2014
# 11285  4ee7cec5-a50e-491b-ab49-a94620beb900       2012
